# %%
from qiskit import QuantumCircuit, execute
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram

# Initialize a 2-qubit circuit
qc = QuantumCircuit(2, 2)

# 1. Initialize (Implicitly in |00> state)
# 2. Apply Hadamard to qubit 0
qc.h(0)

# 3. Apply CNOT (Control: 0, Target: 1)
qc.cx(0, 1)

# 4. Measure both
qc.measure([0, 1], [0, 1])

# Simulation
backend = Aer.get_backend('qasm_simulator')
job = execute(qc, backend, shots=1024)
result = job.result().get_counts()
print(result)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from qiskit import QuantumCircuit, Aer, execute
#       2 from qiskit.visualization import plot_histogram
#       3
#       4 # Initialize a 2-qubit circuit
#
# ImportError: cannot import name 'Aer' from 'qiskit' (/home/soham/MyVenv/.venv/lib/python3.12/site-packages/qiskit/__init__.py)

# %%
# %pip install qiskit
# Out:
# Collecting qiskit
#   Using cached qiskit-2.3.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (12 kB)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Using cached rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting numpy<3,>=1.21 (from qiskit)
#   Using cached numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting scipy>=1.5 (from qiskit)
#   Using cached scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting dill>=0.3 (from qiskit)
#   Using cached dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Using cached stevedore-5.7.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting typing-extensions (from qiskit)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Using cached qiskit-2.3.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
# Using cached dill-0.4.1-py3-none-any.whl (120 kB)
# Using cached numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Using cached rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
# Using cached scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
# Using cached stevedore-5.7.0-py3-none-any.whl (54 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing-extensions, stevedore, numpy, dill, scipy, rustworkx, qiskit
# Successfully installed dill-0.4.1 numpy-2.4.4 qiskit-2.3.1 rustworkx-0.17.1 scipy-1.17.1 stevedore-5.7.0 typing-extensions-4.15.0
# Note: you may need to restart the kernel to use updated packages.
